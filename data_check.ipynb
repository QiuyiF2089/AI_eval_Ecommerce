# %%
import pandas as pd

# %%
data1=pd.read_csv('/Users/fengqiuyi/ESales_eval/data/complete_results.csv')
print(data1.head(1))
# Out:
#                                                 name        main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  tv, audio & cameras
#
#       sub_category                                              image  \
# 0  All Electronics  https://m.media-amazon.com/images/I/81eM15lVcJ...
#
#                                                 link no_of_ratings  \
# 0  https://www.amazon.in/Redmi-Power-Black-128GB-...           965
#
#   discount_price actual_price       review_rating original_review_text  ...  \
# 0        ₹10,999      ₹18,999  3.0 out of 5 stars                NOTE:  ...
#
#   t5_rouge1  t5_rouge2  t5_rougeL  t5_avg_rouge  best_model  \
# 0       0.0        0.0        0.0           0.0        BART
#
#                                     raw_best_summary  best_avg_score  \
# 0  WARNING: GRAPHIC CONTENT. CLICK HERE to read t...             0.0
#
#                                    cleaned_narrative  qwen_used  \
# ...
